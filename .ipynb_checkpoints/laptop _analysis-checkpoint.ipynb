# %% [markdown]
# # LAPTOP ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
data=pd.read_csv('laptop.csv')

# %%
data.head()
# Out:
#    Unnamed: 0    Brand                                               Name  \
# 0           0       HP  HP Chromebook 11A-NA0002MU (2E4N0PA) Laptop (1...
# 1           1   Lenovo  Lenovo Ideapad Slim 3 (82KU017KIN) Laptop (15....
# 2           3     Dell  Dell G15-5520 (D560822WIN9B) Laptop (15.6 Inch...
# 3           4       HP  HP 15s-fy5007TU (91R03PA) Laptop (15.6 Inch | ...
# 4           6  Infinix  Infinix Inbook Y2 Plus XL29 Laptop (15.6 Inch ...
#
#    Price            Processor_Name Processor_Brand     RAM_Expandable  \
# 0  22990        MediaTek Octa-core        MediaTek     Not Expandable
# 1  36289     AMD Hexa-Core Ryzen 5             AMD   12 GB Expandable
# 2  78500  Intel Core i5 (12th Gen)           Intel   32 GB Expandable
# 3  55490  Intel Core i5 (12th Gen)           Intel    8 GB Expandable
# 4  21990  Intel Core i3 (11th Gen)           Intel     Not Expandable
#
#        RAM      RAM_TYPE                 Ghz Display_type Display  \
# 0    4 GB       DDR4 RAM   2.0 Ghz Processor          LED   11.6
# 1    8 GB      DDR4 RAM    4.0 Ghz Processor          LCD   15.6
# 2   16 GB      DDR5 RAM    3.3 Ghz Processor          LCD   15.6
# 3    8 GB      DDR4 RAM    4.2 Ghz Processor          LCD   15.6
# 4  8 GB LP   LPDDR4X RAM   1.7 Ghz Processor          LCD   15.6
#
#                           GPU GPU_Brand                 SSD     HDD Adapter  \
# 0         Integrated Graphics  MediaTek   64 GB SSD Storage  No HDD      45
# 1                      Radeon       AMD  512 GB SSD Storage  No HDD      65
# 2  GeForce RTX 3050 GPU, 4 GB    NVIDIA  512 GB SSD Storage  No HDD      56
# 3                     Iris Xe     Intel  512 GB SSD Storage  No HDD      no
# 4                         UHD     Intel  512 GB SSD Storage  No HDD      45
#
#                  Battery_Life
# 0    Upto 12 Hrs Battery Life
# 1    Upto 11 Hrs Battery Life
# 2    Upto 10 Hrs Battery Life
# 3  Upto 7.30 Hrs Battery Life
# 4     Upto 8 Hrs Battery Life

# %%
data.shape
# Out:
# (3976, 18)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Brand', 'Name', 'Price', 'Processor_Name',
#        'Processor_Brand', 'RAM_Expandable', 'RAM', 'RAM_TYPE', 'Ghz',
#        'Display_type', 'Display', 'GPU', 'GPU_Brand', 'SSD', 'HDD', 'Adapter',
#        'Battery_Life'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)
data.columns
# Out:
# Index(['Brand', 'Name', 'Price', 'Processor_Name', 'Processor_Brand',
#        'RAM_Expandable', 'RAM', 'RAM_TYPE', 'Ghz', 'Display_type', 'Display',
#        'GPU', 'GPU_Brand', 'SSD', 'HDD', 'Adapter', 'Battery_Life'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Price
# count    3976.000000
# mean    72432.528672
# std     52207.650948
# min      7990.000000
# 25%     39873.250000
# 50%     58990.000000
# 75%     84990.000000
# max    503890.000000

# %%
data.isna().sum()
# Out:
# Brand                0
# Name                 0
# Price                0
# Processor_Name       0
# Processor_Brand      0
# RAM_Expandable       0
# RAM                  0
# RAM_TYPE             0
# Ghz                  0
# Display_type         0
# Display              0
# GPU                  8
# GPU_Brand            4
# SSD                  0
# HDD                  0
# Adapter              0
# Battery_Life       418
# dtype: int64

# %%
data.dropna(inplace=True)
data.isna().sum()
# Out:
# Brand              0
# Name               0
# Price              0
# Processor_Name     0
# Processor_Brand    0
# RAM_Expandable     0
# RAM                0
# RAM_TYPE           0
# Ghz                0
# Display_type       0
# Display            0
# GPU                0
# GPU_Brand          0
# SSD                0
# HDD                0
# Adapter            0
# Battery_Life       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3546 entries, 0 to 3975
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            3546 non-null   object
#  1   Name             3546 non-null   object
#  2   Price            3546 non-null   int64
#  3   Processor_Name   3546 non-null   object
#  4   Processor_Brand  3546 non-null   object
#  5   RAM_Expandable   3546 non-null   object
#  6   RAM              3546 non-null   object
#  7   RAM_TYPE         3546 non-null   object
#  8   Ghz              3546 non-null   object
#  9   Display_type     3546 non-null   object
#  10  Display          3546 non-null   object
#  11  GPU              3546 non-null   object
#  12  GPU_Brand        3546 non-null   object
#  13  SSD              3546 non-null   object
#  14  HDD              3546 non-null   object
#  15  Adapter          3546 non-null   object
#  16  Battery_Life     3546 non-null   object
# dtypes: int64(1), object(16)
# memory usage: 498.7+ KB

# %%
print(data.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3971    False
# 3972    False
# 3973    False
# 3974    False
# 3975    False
# Length: 3546, dtype: bool

# %%
#data.drop_duplicates(inplace=True) if duplicate present

# %%
data.Brand.unique()
# Out:
# array(['HP', 'Lenovo', 'Dell', 'Infinix', 'Acer', 'ASUS', 'Tecno',
#        'Xiaomi', 'MSI', 'Samsung', 'Apple', 'Realme', 'AVITA',
#        'Zebronics', 'Honor', 'Fujitsu', 'Wings', 'LG', 'Microsoft',
#        'Razer', 'Coconics', 'Gigabyte', 'Huawei', 'Micromax', 'iball',
#        'Lava', 'VAIO', 'Smartron', 'Colorful', 'Nokia', 'RDP'],
#       dtype=object)

# %%
brand_sales=data['Brand'].value_counts()
brand_sales
# Out:
# Brand
# ASUS         926
# Lenovo       755
# HP           728
# Dell         367
# Acer         301
# MSI          179
# Samsung       56
# Apple         47
# Infinix       39
# Microsoft     34
# AVITA         20
# LG            15
# Honor         14
# Xiaomi        10
# Zebronics      8
# Fujitsu        8
# iball          8
# Gigabyte       5
# Wings          4
# Colorful       3
# Realme         3
# Micromax       3
# Coconics       3
# Tecno          2
# Smartron       2
# Huawei         1
# Razer          1
# VAIO           1
# Lava           1
# Nokia          1
# RDP            1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.set_style('whitegrid')
sns.countplot(data=data,y='Brand',hue='Brand')
plt.title('count of sales')
plt.xlabel('number of laptops');

# %%
# checking for outliers
fig,ax=plt.subplots(1,2,figsize=(8,4))
sns.boxplot(data=data,x='Price',ax=ax[0]).set(title='box plot of price')
sns.kdeplot(data=data,x='Price',ax=ax[1]).set(title='kde plot of price')
plt.tight_layout();

# %%
# iqr method for removal of outliers
q1=data['Price'].quantile(0.25)
q3=data['Price'].quantile(0.75)
iqr=q3-q1
print(q1,q3,iqr)
# Out:
# 39298.25 84990.0 45691.75

# %%
upper_limit=q3+(1.5*iqr)
lower_limit=q1-(1.5*iqr)
print(lower_limit,upper_limit)
# Out:
# -29239.375 153527.625

# %%
new_data=data.loc[(data['Price']<upper_limit) & (data['Price']>lower_limit)]
print('before removing outlier :',len(data))
print('aftre removing outlier :',len(new_data))
print('outlier :',len(data)-len(new_data))
# Out:
# before removing outlier : 3546
# aftre removing outlier : 3305
# outlier : 241

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))
sns.boxplot(data=new_data,x='Price',ax=ax[0]).set(title='box plot of price')
sns.kdeplot(data=new_data,x='Price',ax=ax[1]).set(title='kde plot of price')
plt.tight_layout();

# %%
new_df_cap=data.copy()
new_df_cap['Price']=np.where(new_df_cap['Price']>upper_limit,upper_limit,new_df_cap['Price'])

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))
sns.boxplot(data=new_df_cap,x='Price',ax=ax[0]).set(title='box plot of price')
sns.kdeplot(data=new_df_cap,x='Price',ax=ax[1]).set(title='kde plot of price')
plt.tight_layout();

# %%
sns.stripplot(data=data,x='Price',y='Processor_Brand',hue='Processor_Brand').set(title='processor brand distribution over price');

# %%
sns.stripplot(data=data,x='Price',y='RAM',hue='RAM').set(title='ram distribution over price');

# %%
sns.stripplot(data=data,x='Price',y='Brand',hue='Brand').set(title=' Brand distribution over price');

# %%
fig,ax=plt.subplots(1,2,figsize=(10,10))
sns.stripplot(data=data,x='Price',y='HDD',hue='HDD',ax=ax[0]).set(title='HDD brand distribution over price')
sns.stripplot(data=data,x='Price',y='SSD',hue='SSD',ax=ax[1]).set(title='SSD distribuion over price')
plt.tight_layout();

# %% [markdown]
# ## EDA + LAPTOP RECOMMENDATION REPORT

# %%
df=new_df_cap.copy()
df1=data.copy()

# %% [markdown]
# ##### helper function to extract numerical values

# %%
def extract_int(text):
    if pd.isna(text):return np.nan
    s=str(text)
    m=re.search(r'(\d+)',s)
    return int(m.group(1))if m else np.nan

# %%
def extract_storage_gb(text):
    if pd.isna(text):return 0
    s=str(text).lower()
    total=0
    for m in re.finditer(r'(\d+)\s*gb',s):
        total+=int(m.group(1))
    for m in re.finditer(r'(\d+)\s*tb',s):
        total+=int(m.group(1))*1000
    if total==0:
         m=re.search(r'(\d+)',s)
         total=int(m.group(1))if m else 0
    return total

# %%
def extract_ghz(text):
    if pd.isna(text):return np.nan
    s=str(text)
    m=re.search(r'([\d\.]+)\s*ghz',s,flags=re.IGNORECASE)
    if m:
        return float(m.group(1))
        m2=re.search(r'[\d\.]+)',s)
        return float(m2.group(1)) if m2 else np.nan

# %%
def extract_battery_hours(text):
    if pd.isna(text): return np.nan
    s=str(text).lower()
    m=re.search(r'([\d\.]+)\s*(hours/hrs/hr/h)\b',s)
    if m: return float(m.group(1))
    m2=re.search(r'([\d\.]+)',s)
    return float(m2.group(1)) if m2 else np.nan

# %%
def extractModel(x):
    lb=str(x).split()
    model="".join(lb[1:2])
    return model

# %% [markdown]
# #####  extract numeric feature

# %%
df['RAM_GB']=df['RAM'].astype(str).apply(extract_int).astype(int)
df['SSD_GB']=df['SSD'].astype(str).apply(extract_storage_gb).astype(int)
df['HDD_GB']=df['HDD'].astype(str).apply(extract_storage_gb).astype(int)
df['Total_Storage_GB']=df['SSD_GB']+df['HDD_GB']
df['Ghz_num']=df['Ghz'].astype(str).apply(extract_ghz).astype(float)
df['Battery_hours']=df['Battery_Life'].astype(str).apply(extract_battery_hours).astype(float)
df['GPU_Brand']=df['GPU_Brand'].fillna('Unknown')
df['Has_SSD']=df['SSD_GB']>0
df['Model']=data['Name'].apply(extractModel)

# %%
df_col=['Brand','Model','Price','RAM','RAM_GB','SSD','SSD_GB','GPU','GPU_Brand','Ghz','Ghz_num','Battery_Life','Battery_hours']
sample=df[df_col].head()
sample.head()
# Out:
#      Brand         Model    Price      RAM  RAM_GB                 SSD  \
# 0       HP    Chromebook  22990.0    4 GB        4   64 GB SSD Storage
# 1   Lenovo       Ideapad  36289.0    8 GB        8  512 GB SSD Storage
# 2     Dell      G15-5520  78500.0   16 GB       16  512 GB SSD Storage
# 3       HP  15s-fy5007TU  55490.0    8 GB        8  512 GB SSD Storage
# 4  Infinix        Inbook  21990.0  8 GB LP       8  512 GB SSD Storage
#
#    SSD_GB                         GPU GPU_Brand                 Ghz  Ghz_num  \
# 0      64         Integrated Graphics  MediaTek   2.0 Ghz Processor      2.0
# 1     512                      Radeon       AMD   4.0 Ghz Processor      4.0
# 2     512  GeForce RTX 3050 GPU, 4 GB    NVIDIA   3.3 Ghz Processor      3.3
# 3     512                     Iris Xe     Intel   4.2 Ghz Processor      4.2
# 4     512                         UHD     Intel   1.7 Ghz Processor      1.7
#
#                  Battery_Life  Battery_hours
# 0    Upto 12 Hrs Battery Life           12.0
# 1    Upto 11 Hrs Battery Life           11.0
# 2    Upto 10 Hrs Battery Life           10.0
# 3  Upto 7.30 Hrs Battery Life            7.3
# 4     Upto 8 Hrs Battery Life            8.0

# %%
num_cols=['Price','RAM_GB','SSD_GB','HDD_GB','Total_Storage_GB','Ghz_num','Battery_hours']
num_summary=df[num_cols].describe()
print(num_summary)
# Out:
#                Price       RAM_GB       SSD_GB       HDD_GB  Total_Storage_GB  \
# count    3546.000000  3546.000000  3546.000000  3546.000000       3546.000000
# mean    67523.125670    11.000000   452.027919   253.840102        705.868020
# std     36924.823389     6.220762   340.432478   450.744481        354.271578
# min      7990.000000     2.000000     0.000000     0.000000          1.000000
# 25%     39298.250000     8.000000   256.000000     0.000000        512.000000
# 50%     58490.000000     8.000000   512.000000     0.000000        512.000000
# 75%     84990.000000    16.000000   512.000000     0.000000       1024.000000
# max    153527.625000    64.000000  4098.000000  2048.000000       4098.000000
#
#            Ghz_num  Battery_hours
# count  3334.000000    3546.000000
# mean      2.726815      51.466277
# std       1.112642      58.435142
# min       0.800000       2.250000
# 25%       2.000000       8.800000
# 50%       2.500000      42.000000
# 75%       3.400000      65.000000
# max       5.500000     330.000000

# %% [markdown]
# #----top brands and price status---

# %%
brand_count=df['Brand'].value_counts().reset_index().rename(columns={'index':'Brand','Brand':'Count'})
brand_price_stat=df.groupby('Brand')['Price'].agg(['count','mean','median','min','max']).sort_values('count',ascending=False).reset_index()
print(brand_count.head(20).to_string(index=False))
print(brand_price_stat.head(20).to_string(index=False))
# Out:
#     Count  count
#      ASUS    926
#    Lenovo    755
#        HP    728
#      Dell    367
#      Acer    301
#       MSI    179
#   Samsung     56
#     Apple     47
#   Infinix     39
# Microsoft     34
#     AVITA     20
#        LG     15
#     Honor     14
#    Xiaomi     10
# Zebronics      8
#   Fujitsu      8
#     iball      8
#  Gigabyte      5
#     Wings      4
#  Colorful      3
#     Brand  count          mean     median      min        max
#      ASUS    926  71743.687770  62990.000   7990.0 153527.625
#    Lenovo    755  61185.661258  53566.000  17990.0 153527.625
#        HP    728  63099.205529  54794.000  17994.0 153527.625
#      Dell    367  64652.471049  55532.000  19990.0 153527.625
#      Acer    301  56953.296927  50131.000  12437.0 153527.625
#       MSI    179  91900.909916  84990.000  29800.0 153527.625
#   Samsung     56 104711.236607 109490.000  30990.0 153527.625
#     Apple     47 124265.093085 127990.000  67990.0 153527.625
#   Infinix     39  43691.461538  36490.000  20290.0  99990.000
# Microsoft     34 108154.452206  99990.000  49990.0 153527.625
#     AVITA     20  41106.950000  38990.000  15990.0 132590.000
#        LG     15  94177.908333  89799.000  39990.0 153527.625
#     Honor     14  47223.928571  45440.000  35865.0  58990.000
#    Xiaomi     10  49589.900000  42494.500  24642.0  84104.000
#   Fujitsu      8  80590.000000  79090.000  68990.0  99990.000
#     iball      8  12719.875000  12244.500   9990.0  16900.000
# Zebronics      8  36990.000000  34990.000  22990.0  52990.000
#  Gigabyte      5 144201.500000 153527.625 106897.0 153527.625
#     Wings      4  32490.000000  27490.000  24990.0  49990.000
#  Micromax      3  12662.666667  10490.000   9499.0  17999.000

# %%
plt.figure(figsize=(8,4))
brand_count=new_df_cap['Brand'].value_counts().reset_index()
brand_count.column=['Brand','Count']
top_brands=brand_count.head(10)['Brand'].tolist()
data_for_box=[new_df_cap[new_df_cap['Brand']==b]['Price'].values for b in top_brands]
plt.boxplot(data_for_box, labels=top_brands)
plt.title('Price by brands(top 10 brands)')
plt.ylabel('price')
plt.show();
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3912\2494540613.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   brand_count.column=['Brand','Count']
# C:\Users\User\AppData\Local\Temp\ipykernel_3912\2494540613.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_for_box, labels=top_brands)

# %%
df.groupby('Model').count().Name.sort_values(ascending=False)[0:10].plot.bar()
plt.ylabel('number of laptop')
plt.title('top 10 laptop models for sale');

# %%
df.groupby('Brand').count().Name.sort_values(ascending=False)[0:10].plot.bar()
plt.ylabel('number of laptop')
plt.title('top 10 laptop brands for sale');

# %%
plt.figure(figsize=(8,5))
plt.scatter(df['RAM_GB'],df['Price'],alpha=0.3)
plt.title('price vs RAM-gb')
plt.xlabel('ram_gb')
plt.ylabel('price');

# %%
plt.figure(figsize=(8,6))
sns.stripplot(data=df,y='Price',x='Total_Storage_GB').set(title='total storage gb distribution over price');

# %%
h=df[num_cols].corr().Price.sort_values(ascending=False)
h
# Out:
# Price               1.000000
# RAM_GB              0.717147
# SSD_GB              0.657061
# Battery_hours       0.350722
# Ghz_num             0.344853
# Total_Storage_GB    0.267143
# HDD_GB             -0.286290
# Name: Price, dtype: float64

# %%
sns.heatmap(df[num_cols].corr(),cmap='Spectral');

# %% [markdown]
# ### laptop recommendation

# %%
gpu_mask=df['GPU'].astype(str).str.contains('nvidia/rtx/gtx/geforce/radeon/amd', case=False,na=False)

# %%
# for students recommendation
students=df[(df['Price']<=60000)&(df['Battery_hours']>=6)&(df['RAM_GB']>=8)].sort_values(['Price','Battery_hours'],ascending=[True,False])
students_rec=students[['Brand','Price','RAM_GB','SSD_GB','Total_Storage_GB','GPU_Brand','Ghz_num','Battery_hours']].head(10)
print('students recommendation is:\n',students_rec)
# Out:
# students recommendation is:
#            Brand    Price  RAM_GB  SSD_GB  Total_Storage_GB GPU_Brand  Ghz_num  \
# 2976       ASUS  20599.0       8     256               256       AMD      2.6
# 3034       ASUS  21990.0       8     256               256     Intel      1.1
# 4       Infinix  21990.0       8     512               512     Intel      1.7
# 1866     Lenovo  22890.0       8     256               256     Intel      1.1
# 1518         HP  22899.0       8     256               256     Intel      3.4
# 3693      AVITA  22990.0       8     256               256       AMD      3.0
# 862        ASUS  22990.0       8     256               256     Intel      1.1
# 2069  Zebronics  22990.0       8     512               512     Intel      2.4
# 1723       Dell  23819.0       8     256               256     Intel      1.1
# 1451     Xiaomi  24642.0       8     512               512    NVIDIA      1.6
#
#       Battery_hours
# 2976           45.0
# 3034           33.0
# 4               8.0
# 1866            6.0
# 1518           12.0
# 3693           36.7
# 862            33.0
# 2069           10.0
# 1723            7.0
# 1451           65.0

# %%
students_rec.groupby('Brand').count().Price.sort_values(ascending=False)[0:10].plot.bar()
plt.ylabel('no.of laptops')
plt.title('top 10 laptop brands for students');

# %%
gamers=df[gpu_mask & (df['RAM_GB']>=16) & (df['Price']>=60000)].copy()
gamers['score']=gamers['RAM_GB']*2 + gamers['SSD_GB']/100 + gamers['Ghz_num'].fillna(0)
gamers=gamers.sort_values(['score','Price'],ascending=[True,False])
gamers_rec=gamers[['Brand','Price','RAM_GB','SSD_GB','GPU','GPU_Brand','Ghz_num']].head(10)
print('gamers recommendation is:\n', gamers_rec)
# Out:
# gamers recommendation is:
#  Empty DataFrame
# Columns: [Brand, Price, RAM_GB, SSD_GB, GPU, GPU_Brand, Ghz_num]
# Index: []

# %%
professional=df[(df['RAM_GB']>=16)&(df['SSD_GB']>=512)&(df['Ghz_num']>=2.5)].sort_values(['Price','Ghz_num'],ascending=[True,False])
professional_rec=professional[['Brand','Price','RAM_GB','SSD_GB','Total_Storage_GB','Battery_hours','Ghz_num']].head(10)
print('professional recommendation is :\n' , professional_rec)
# Out:
# professional recommendation is :
#            Brand    Price  RAM_GB  SSD_GB  Total_Storage_GB  Battery_hours  \
# 3248    Infinix  30990.0      16     512               512           11.0
# 2014       ASUS  34999.0      16     512               512           45.0
# 1006       Dell  35990.0      16     512               512           65.0
# 819        ASUS  35990.0      16     512               512           45.0
# 3279    Infinix  36990.0      16    1024              1024           11.0
# 3216    Infinix  39990.0      16     512               512           10.0
# 291   Zebronics  39990.0      16     512               512           10.0
# 3171       Acer  40990.0      16     512               512           45.0
# 24       Lenovo  40990.0      16     512               512            7.0
# 2861         HP  42084.0      16     512               512            9.0
#
#       Ghz_num
# 3248      3.0
# 2014      3.0
# 1006      4.2
# 819       3.0
# 3279      2.5
# 3216      4.7
# 291       4.2
# 3171      3.3
# 24        2.5
# 2861      4.0

# %%
professional_rec.groupby('Brand').count().Price.sort_values(ascending=False)[0:10].plot.bar()
plt.ylabel('no.of laptops')
plt.title('top 10 laptop brands for professional');

# %% [markdown]
# ### price prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
#creating the residual versus fitted plot with outliers
X=df1[features]
y=df1['Price']
X=X.fillna(0)
y=y.fillna(y.median())
le=LabelEncoder()
for col in ['Brand','Processor_Brand','GPU_Brand']:
    X[col]=le.fit_transform(X[col].astype(str))
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
residuals=y_test-y_pred
plt.scatter(y_pred,residuals)
plt.axhline(y=0,color='r',linestyle='--')
plt.xlabel('fitted values')
plt.ylabel('residuals')
plt.title('residual vs fitted values');

# %%
#creating the residual versus fitted plot without outliers
X=df[features]
y=df['Price']
X=X.fillna(0)
y=y.fillna(y.median())
le=LabelEncoder()
for col in ['Brand','Processor_Brand','GPU_Brand']:
    X[col]=le.fit_transform(X[col].astype(str))
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
residuals=y_test-y_pred
plt.scatter(y_pred,residuals)
plt.axhline(y=0,color='r',linestyle='--')
plt.xlabel('fitted values')
plt.ylabel('residuals')
plt.title('residual vs fitted values without liers');

# %% [markdown]
# ###### conclusion : here we see some heteroscedacticity in the above graph so we apply log transformation to our dependent variable price

# %%
import statsmodels.api as sm
sm.qqplot(np.log(df['Price']),line='s')
plt.title('qq plot of sample data vs normal distribution without outliers');

# %%
import statsmodels.api as sm
sm.qqplot(np.log(df1['Price']),line='s')
plt.title('qq plot of sample data vs normal distribution with outliers');

# %%
# without outliers model performance 

features=['Brand','Total_Storage_GB','Processor_Brand','RAM_GB','GPU_Brand','Ghz_num','Battery_hours']
X=df[features]
y=np.log(df['Price'])
#handling missing values
X=X.fillna(0)
y=y.fillna(y.median())

#encode categorical columns
le=LabelEncoder()
for col in ['Brand','Processor_Brand','GPU_Brand']:
    X[col]=le.fit_transform(X[col].astype(str))
# scale numeric feature
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
#split train and test set
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=42)
#define model
models={
    'linear regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(random_state=42)
}
    

for name,model in models.items():
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print(name,'accuracy score for test data ',round(r2_score(y_test,y_pred),2))
    print(name,'rmse',round(np.sqrt(mean_squared_error(y_test,y_pred)),2))
    y_pred=model.predict(X_train)
    print(name,'accuracy score for train data',round(r2_score(y_train,y_pred),2))
# Out:
# linear regression accuracy score for test data  0.6
# linear regression rmse 0.34
# linear regression accuracy score for train data 0.57
# Random Forest accuracy score for test data  0.8
# Random Forest rmse 0.24
# Random Forest accuracy score for train data 0.95

# %%
# with outlier model performance

df1['RAM_GB']=df1['RAM'].astype(str).apply(extract_int)
df1['SSD_GB']=df1['SSD'].astype(str).apply(extract_storage_gb)
df1['HDD_GB']=df1['HDD'].astype(str).apply(extract_storage_gb)
df1['Total_Storage_GB']=df1['SSD_GB']+df1['HDD_GB']
df1['Ghz_num']=df1['Ghz'].astype(str).apply(extract_ghz)
df1['Battery_hours']=df1['Battery_Life'].astype(str).apply(extract_battery_hours)
df1['GPU_Brand']=df1['GPU_Brand'].fillna('Unknown')
df1['Has_SSD']=df1['SSD_GB']>0

df1_col=['Brand','Price','RAM','RAM_GB','SSD','SSD_GB','GPU','GPU_Brand','Ghz','Ghz_num','Battery_Life','Battery_hours']
sample=df1[df1_col].head(6)
sample.head(6)

num_cols=['Price','RAM_GB','SSD_GB','HDD_GB','Total_Storage_GB','Ghz_num','Battery_hours']
num_summary=df1[num_cols].describe()

features=['Brand','Processor_Brand','RAM_GB','Total_Storage_GB','Ghz_num','Battery_hours','GPU_Brand']
X=df1[features]
y=np.log(df1['Price'])
#handling missing values
X=X.fillna(0)
y=y.fillna(y.median())

#encode categorical columns
le=LabelEncoder()
for col in ['Brand','Processor_Brand','GPU_Brand']:
    X[col]=le.fit_transform(X[col].astype(str))
# scale numeric feature
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
#split train and test set
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=42)
#define model
models={
    'linear regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(random_state=42),
   }

for name,model in models.items():
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print(name,'accuracy score for test data',round(r2_score(y_test,y_pred),2))
    print(name,'rmse',round(np.sqrt(mean_squared_error(y_test,y_pred)),2))
    y_pred=model.predict(X_train)
    print(name,'accuracy score for train data',round(r2_score(y_train,y_pred),2))
# Out:
# linear regression accuracy score for test data 0.64
# linear regression rmse 0.35
# linear regression accuracy score for train data 0.62
# Random Forest accuracy score for test data 0.81
# Random Forest rmse 0.26
# Random Forest accuracy score for train data 0.95

# %% [markdown]
# ##### feature importance for linear regression

# %%
model1=LinearRegression()
model1.fit(X_train,y_train)
coefficients=model1.coef_
feature_names=X.columns
feature_importance=pd.DataFrame({'Feature':feature_names,'coefficient':coefficients})
feature_importance['Absolute_Coefficient']=abs(feature_importance['coefficient'])
feature_importance=feature_importance.sort_values(by='Absolute_Coefficient',ascending=False)
print(feature_importance)
# Out:
#             Feature  coefficient  Absolute_Coefficient
# 2            RAM_GB     0.369184              0.369184
# 6         GPU_Brand     0.132564              0.132564
# 5     Battery_hours     0.043057              0.043057
# 3  Total_Storage_GB     0.036739              0.036739
# 4           Ghz_num     0.035317              0.035317
# 1   Processor_Brand    -0.009176              0.009176
# 0             Brand     0.005975              0.005975

# %%
plt.barh(feature_importance['Feature'],feature_importance['Absolute_Coefficient'])
plt.xlabel('importance')
plt.ylabel('feature')
plt.title('linear regression features importances')
plt.gca().invert_yaxis(); #to display the most important features

# %% [markdown]
# ##### feature extraction in random forest

# %%
rf_model=RandomForestRegressor(random_state=42)
rf_model.fit(X_train,y_train)
Importances=rf_model.feature_importances_
feature_importance_df=pd.DataFrame({'feature': features,'Importance': Importances})
feature_importance_df=feature_importance_df.sort_values(by='Importance',ascending=False)
print('FEATURE IMPORTANCE',feature_importance_df)
# Out:
# FEATURE IMPORTANCE             feature  Importance
# 2            RAM_GB    0.566370
# 3  Total_Storage_GB    0.118698
# 5     Battery_hours    0.087048
# 4           Ghz_num    0.081985
# 0             Brand    0.073890
# 6         GPU_Brand    0.050480
# 1   Processor_Brand    0.021530

# %%
plt.barh(feature_importance_df['feature'],feature_importance_df['Importance'])
plt.xlabel('importance')
plt.ylabel('feature')
plt.title('random forest features importances')
plt.gca().invert_yaxis(); #to display the most important features
